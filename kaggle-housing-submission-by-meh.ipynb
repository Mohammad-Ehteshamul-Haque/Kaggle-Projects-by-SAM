# %% [markdown]
# <a href="https://www.kaggle.com/code/haquee/kaggle-housing-submission-by-meh?scriptVersionId=310326152" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
import pandas as pd
import numpy as np
from scipy import stats
from sklearn.metrics import mean_squared_error

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score
from sklearn.compose import make_column_transformer, ColumnTransformer
from sklearn.pipeline import Pipeline, make_pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OrdinalEncoder, StandardScaler, OneHotEncoder

from sklearn.linear_model import LinearRegression, Ridge
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, VotingRegressor, StackingRegressor
from xgboost import XGBRegressor
from catboost import CatBoostRegressor
import lightgbm as lgb

# %%
train_df = pd.read_csv('/kaggle/input/house-prices-advanced-regression-techniques/train.csv')
test_df = pd.read_csv('/kaggle/input/house-prices-advanced-regression-techniques/test.csv')

# %%
train_df.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
#        'GarageCond', 'PavedDrive', 'WoodDeckSF', 'OpenPorchSF',
#        'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'PoolQC',
#        'Fence', 'MiscFeature', 'MiscVal', 'MoSold', 'YrSold', 'SaleType',
#        'SaleCondition', 'SalePrice'],
#       dtype='object')

# %%
train_df.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# min       1.000000  1872.000000   1950.000000     0.000000     0.000000  ...
# 25%       5.000000  1954.000000   1967.000000     0.000000     0.000000  ...
# 50%       5.000000  1973.000000   1994.000000     0.000000   383.500000  ...
# 75%       6.000000  2000.000000   2004.000000   166.000000   712.250000  ...
# max       9.000000  2010.000000   2010.000000  1600.000000  5644.000000  ...
#
#         WoodDeckSF  OpenPorchSF  EnclosedPorch    3SsnPorch  ScreenPorch  \
# count  1460.000000  1460.000000    1460.000000  1460.000000  1460.000000
# mean     94.244521    46.660274      21.954110     3.409589    15.060959
# std     125.338794    66.256028      61.119149    29.317331    55.757415
# min       0.000000     0.000000       0.000000     0.000000     0.000000
# 25%       0.000000     0.000000       0.000000     0.000000     0.000000
# 50%       0.000000    25.000000       0.000000     0.000000     0.000000
# 75%     168.000000    68.000000       0.000000     0.000000     0.000000
# max     857.000000   547.000000     552.000000   508.000000   480.000000
#
#           PoolArea       MiscVal       MoSold       YrSold      SalePrice
# count  1460.000000   1460.000000  1460.000000  1460.000000    1460.000000
# mean      2.758904     43.489041     6.321918  2007.815753  180921.195890
# std      40.177307    496.123024     2.703626     1.328095   79442.502883
# min       0.000000      0.000000     1.000000  2006.000000   34900.000000
# 25%       0.000000      0.000000     5.000000  2007.000000  129975.000000
# 50%       0.000000      0.000000     6.000000  2008.000000  163000.000000
# 75%       0.000000      0.000000     8.000000  2009.000000  214000.000000
# max     738.000000  15500.000000    12.000000  2010.000000  755000.000000
#
# [8 rows x 38 columns]

# %%
train_df.dtypes[train_df.dtypes != 'object']
# Out:
# Id                 int64
# MSSubClass         int64
# LotFrontage      float64
# LotArea            int64
# OverallQual        int64
# OverallCond        int64
# YearBuilt          int64
# YearRemodAdd       int64
# MasVnrArea       float64
# BsmtFinSF1         int64
# BsmtFinSF2         int64
# BsmtUnfSF          int64
# TotalBsmtSF        int64
# 1stFlrSF           int64
# 2ndFlrSF           int64
# LowQualFinSF       int64
# GrLivArea          int64
# BsmtFullBath       int64
# BsmtHalfBath       int64
# FullBath           int64
# HalfBath           int64
# BedroomAbvGr       int64
# KitchenAbvGr       int64
# TotRmsAbvGrd       int64
# Fireplaces         int64
# GarageYrBlt      float64
# GarageCars         int64
# GarageArea         int64
# WoodDeckSF         int64
# OpenPorchSF        int64
# EnclosedPorch      int64
# 3SsnPorch          int64
# ScreenPorch        int64
# PoolArea           int64
# MiscVal            int64
# MoSold             int64
# YrSold             int64
# SalePrice          int64
# dtype: object

# %%
plt.scatter(x='MSSubClass', y='SalePrice', data=train_df)

# %%
plt.scatter(x='LotFrontage', y='SalePrice', data=train_df)

# %%
# combining the datasets to perform the log on the combined dataset
train_size = train_df.shape[0]
df = pd.concat([train_df, test_df] )

# %%
num_features = df.select_dtypes(include=["int64", "float64"]).columns

df[num_features].hist(figsize=(20,15), bins=40)
plt.show()

# %%
skew = df[num_features].skew().sort_values(ascending=False)
skew.head(20)
# Out:
# MiscVal          21.958480
# PoolArea         16.907017
# LotArea          12.829025
# LowQualFinSF     12.094977
# 3SsnPorch        11.381914
# KitchenAbvGr      4.304467
# BsmtFinSF2        4.147456
# EnclosedPorch     4.005950
# ScreenPorch       3.948723
# BsmtHalfBath      3.932018
# MasVnrArea        2.602589
# OpenPorchSF       2.536417
# SalePrice         1.882876
# WoodDeckSF        1.843380
# LotFrontage       1.503278
# 1stFlrSF          1.470360
# BsmtFinSF1        1.425722
# MSSubClass        1.376165
# GrLivArea         1.270010
# TotalBsmtSF       1.162882
# dtype: float64

# %%
cols_to_log = [
"LotArea", "BsmtFinSF2", 
]

df[cols_to_log] = np.log1p(df[cols_to_log])

# %%
df["MiscVal"].value_counts()
# Out:
# MiscVal
# 0        2816
# 400        18
# 500        13
# 450         9
# 600         8
# 2000        7
# 700         7
# 1500        3
# 650         3
# 1200        3
# 480         2
# 2500        2
# 3000        2
# 4500        2
# 750         1
# 900         1
# 17000       1
# 6500        1
# 1000        1
# 80          1
# 1512        1
# 455         1
# 460         1
# 490         1
# 1150        1
# 300         1
# 12500       1
# 8300        1
# 1400        1
# 560         1
# 620         1
# 54          1
# 1300        1
# 3500        1
# 800         1
# 15500       1
# 350         1
# 420         1
# Name: count, dtype: int64

# %%
df["PoolArea"].value_counts()
# Out:
# PoolArea
# 0      2906
# 512       1
# 648       1
# 576       1
# 555       1
# 480       1
# 519       1
# 738       1
# 144       1
# 368       1
# 444       1
# 228       1
# 561       1
# 800       1
# Name: count, dtype: int64

# %%
df["LowQualFinSF"].value_counts()
# Out:
# LowQualFinSF
# 0       2879
# 80         4
# 205        2
# 360        2
# 512        1
# 697        1
# 108        1
# 312        1
# 259        1
# 514        1
# 431        1
# 1064       1
# 362        1
# 384        1
# 114        1
# 140        1
# 479        1
# 397        1
# 436        1
# 120        1
# 481        1
# 232        1
# 53         1
# 515        1
# 156        1
# 473        1
# 420        1
# 390        1
# 371        1
# 392        1
# 144        1
# 572        1
# 528        1
# 234        1
# 513        1
# 450        1
# Name: count, dtype: int64

# %%
df["BsmtFinSF2"].value_counts()
# Out:
# BsmtFinSF2
# 0.000000    2571
# 5.198497       5
# 5.686975       5
# 6.077642       3
# 6.182085       3
#             ...
# 6.398595       1
# 5.356586       1
# 6.939254       1
# 6.084499       1
# 5.697093       1
# Name: count, Length: 272, dtype: int64

# %%
# for miscvalue, we use a 0 to signify absence of miscellaneous value, and a 1 to show the presence of it
df['MiscVal'] = (df['MiscVal'] > 0).astype(int)

# %%
# if pool area is 0 that means that they have no pool, and if it is 1 that means a pool is present. However, even if a pool is present, different sizes of pool might influence sale price
df['HasPool'] = (df['PoolArea'] > 0).astype(int)
df['LogPoolArea'] = df['PoolArea'].apply(lambda x: np.log1p(x) if x > 0 else 0)
df = df.drop('PoolArea', axis=1)

# %%
# For LowQualFinSF we apply the same idea as pool area
df['HasLowQualFin'] = (df['LowQualFinSF'] > 0).astype(int)
df['LogLowQualFinSF'] = df['LowQualFinSF'].apply(lambda x: np.log1p(x) if x > 0 else 0)
df = df.drop('LowQualFinSF', axis=1)

# %%
df['HasBsmtFinSF1'] = (df['BsmtFinSF1'] > 0).astype(int)
df['LogBsmtFinSF1'] = df['BsmtFinSF1'].apply(lambda x: np.log1p(x) if x > 0 else 0)
df = df.drop('BsmtFinSF1', axis=1)

# %%
# we will now applu
train = df.loc[df["SalePrice"].notnull()].copy()

# %%
# Manually removing extremes
train_df.query('LotFrontage > 300')
#Drop 935, 1299
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 934    935          20       RL        313.0    27650   Pave   NaN      IR2
# 1298  1299          60       RL        313.0    63887   Pave   NaN      IR3
#
#      LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal  \
# 934          HLS    AllPub  ...        0    NaN   NaN         NaN       0
# 1298         Bnk    AllPub  ...      480     Gd   NaN         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# 934      11   2008        WD         Normal     242000
# 1298      1   2008       New        Partial     160000
#
# [2 rows x 81 columns]

# %%
plt.scatter(x='LotArea', y='SalePrice', data=train_df)

# %%
stats.zscore(train_df['LotArea']).sort_values().tail(10)
# Out:
# 384      4.268474
# 457      4.280500
# 769      4.308262
# 1396     4.678682
# 1298     5.348867
# 451      6.037793
# 706     10.486449
# 249     14.881285
# 335     15.448542
# 313     20.518273
# Name: LotArea, dtype: float64

# %%
train_df.query('LotArea > 55000')
# 250, 314, 336, 707
#maybe 1397
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 249    250          50       RL          NaN   159000   Pave   NaN      IR2
# 313    314          20       RL        150.0   215245   Pave   NaN      IR3
# 335    336         190       RL          NaN   164660   Grvl   NaN      IR1
# 451    452          20       RL         62.0    70761   Pave   NaN      IR1
# 706    707          20       RL          NaN   115149   Pave   NaN      IR2
# 1298  1299          60       RL        313.0    63887   Pave   NaN      IR3
# 1396  1397          20       RL          NaN    57200   Pave   NaN      IR1
#
#      LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal  \
# 249          Low    AllPub  ...        0    NaN   NaN        Shed     500
# 313          Low    AllPub  ...        0    NaN   NaN         NaN       0
# 335          HLS    AllPub  ...        0    NaN   NaN        Shed     700
# 451          Low    AllPub  ...        0    NaN   NaN         NaN       0
# 706          Low    AllPub  ...        0    NaN   NaN         NaN       0
# 1298         Bnk    AllPub  ...      480     Gd   NaN         NaN       0
# 1396         Bnk    AllPub  ...        0    NaN   NaN         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# 249       6   2007        WD         Normal     277000
# 313       6   2009        WD         Normal     375000
# 335       8   2008        WD         Normal     228950
# 451      12   2006        WD         Normal     280000
# 706       6   2007        WD         Normal     302000
# 1298      1   2008       New        Partial     160000
# 1396      6   2010        WD         Normal     160000
#
# [7 rows x 81 columns]

# %%
plt.scatter(x='OverallQual', y='SalePrice', data=train_df)

# %%
train_df.query('OverallQual == 10')
#maybe 524
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 58      59          60       RL         66.0    13682   Pave   NaN      IR2
# 185    186          75       RM         90.0    22950   Pave   NaN      IR2
# 224    225          20       RL        103.0    13472   Pave   NaN      Reg
# 389    390          60       RL         96.0    12474   Pave   NaN      Reg
# 440    441          20       RL        105.0    15431   Pave   NaN      Reg
# 515    516          20       RL         94.0    12220   Pave   NaN      Reg
# 523    524          60       RL        130.0    40094   Pave   NaN      IR1
# 583    584          75       RM         75.0    13500   Pave   NaN      Reg
# 591    592          60       RL         97.0    13478   Pave   NaN      IR1
# 691    692          60       RL        104.0    21535   Pave   NaN      IR1
# 825    826          20       RL        114.0    14803   Pave   NaN      Reg
# 994    995          20       RL         96.0    12456   Pave   NaN      Reg
# 1169  1170          60       RL        118.0    35760   Pave   NaN      IR1
# 1182  1183          60       RL        160.0    15623   Pave   NaN      IR1
# 1243  1244          20       RL        107.0    13891   Pave   NaN      Reg
# 1298  1299          60       RL        313.0    63887   Pave   NaN      IR3
# 1373  1374          20       RL          NaN    11400   Pave   NaN      Reg
# 1442  1443          60       FV         85.0    11003   Pave   NaN      Reg
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 58           HLS    AllPub  ...        0    NaN    NaN         NaN       0
# 185          Lvl    AllPub  ...        0    NaN  GdPrv         NaN       0
# 224          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 389          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 440          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 515          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 523          Bnk    AllPub  ...        0    NaN    NaN         NaN       0
# 583          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 591          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 691          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 825          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 994          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1169         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1182         Lvl    AllPub  ...      555     Ex  MnPrv         NaN       0
# 1243         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1298         Bnk    AllPub  ...      480     Gd    NaN         NaN       0
# 1373         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1442         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# 58       10   2006       New        Partial     438780
# 185       6   2006        WD         Normal     475000
# 224       6   2009        WD         Normal     386250
# 389       8   2008       New        Partial     426000
# 440       4   2009        WD         Normal     555000
# 515       9   2009       New        Partial     402861
# 523      10   2007       New        Partial     184750
# 583       7   2008        WD         Normal     325000
# 591       6   2009     ConLI         Normal     451950
# 691       1   2007        WD         Normal     755000
# 825       6   2008       New        Partial     385000
# 994       7   2009        WD         Normal     337500
# 1169      7   2006        WD         Normal     625000
# 1182      7   2007        WD        Abnorml     745000
# 1243      9   2006       New        Partial     465000
# 1298      1   2008       New        Partial     160000
# 1373      3   2007        WD         Normal     466500
# 1442      4   2009        WD         Normal     310000
#
# [18 rows x 81 columns]

# %%
train_df.query('OverallQual == 4').sort_values(by= "SalePrice")
# 458 MAYBE
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 495    496          30  C (all)         60.0     7879   Pave   NaN      Reg
# 30      31          70  C (all)         50.0     8500   Pave  Pave      Reg
# 1337  1338          30       RM        153.0     4118   Pave  Grvl      IR1
# 705    706         190       RM         70.0     5600   Pave   NaN      Reg
# 1325  1326          30       RM         40.0     3636   Pave   NaN      Reg
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 405    406          20       RL          NaN     9991   Pave   NaN      IR1
# 1262  1263          50       RL          NaN    11250   Pave   NaN      Reg
# 1190  1191         190       RL          NaN    32463   Pave   NaN      Reg
# 1020  1021          20       RL         60.0     7024   Pave   NaN      Reg
# 457    458          20       RL          NaN    53227   Pave   NaN      IR1
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 495          Lvl    AllPub  ...        0    NaN   GdWo         NaN       0
# 30           Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 1337         Bnk    AllPub  ...        0    NaN    NaN         NaN       0
# 705          Lvl    AllPub  ...        0    NaN    NaN        Othr    3500
# 1325         Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# ...          ...       ...  ...      ...    ...    ...         ...     ...
# 405          Lvl    AllPub  ...        0    NaN   GdWo         NaN       0
# 1262         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1190         Low    AllPub  ...        0    NaN    NaN         NaN       0
# 1020         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 457          Low    AllPub  ...        0    NaN    NaN         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# 495      11   2009        WD        Abnorml      34900
# 30        7   2008        WD         Normal      40000
# 1337      3   2006        WD         Normal      52500
# 705       7   2010        WD         Normal      55000
# 1325      1   2008        WD         Normal      55000
# ...     ...    ...       ...            ...        ...
# 405       6   2009        WD         Normal     150000
# 1262     11   2009        WD         Normal     161500
# 1190      3   2007        WD         Normal     168000
# 1020      6   2008        WD         Normal     176000
# 457       3   2008        WD         Normal     256000
#
# [116 rows x 81 columns]

# %%
train_df.query("OverallQual == 7").sort_values(by= "SalePrice")
# Maybe 633 (too low sale price compared to overall qual)
# Maybe 113 (too high compared to overallQual)
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 632    633          20       RL         85.0    11900   Pave   NaN      Reg
# 1148  1149          50       RM          NaN     5700   Pave   NaN      Reg
# 1266  1267         190       RM         60.0    10120   Pave   NaN      IR1
# 8        9          50       RM         51.0     6120   Pave   NaN      Reg
# 193    194         160       RM         24.0     2522   Pave   NaN      Reg
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 692    693          60       RL         42.0    26178   Pave   NaN      IR1
# 1310  1311          20       RL        100.0    17500   Pave   NaN      Reg
# 718    719          60       RL         96.0    10542   Pave   NaN      Reg
# 313    314          20       RL        150.0   215245   Pave   NaN      IR3
# 112    113          60       RL         77.0     9965   Pave   NaN      Reg
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 632          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1148         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1266         Bnk    AllPub  ...        0    NaN  MnPrv         NaN       0
# 8            Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 193          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# ...          ...       ...  ...      ...    ...    ...         ...     ...
# 692          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1310         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 718          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 313          Low    AllPub  ...        0    NaN    NaN         NaN       0
# 112          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# 632       4   2009        WD         Family      82500
# 1148      8   2008        WD         Normal     116900
# 1266      1   2007        WD         Normal     122000
# 8         4   2008        WD        Abnorml     129900
# 193       5   2006        WD         Normal     130000
# ...     ...    ...       ...            ...        ...
# 692       4   2006        WD         Normal     335000
# 1310      5   2010        WD         Normal     335000
# 718       8   2008        WD         Normal     341000
# 313       6   2009        WD         Normal     375000
# 112      10   2007       New        Partial     383970
#
# [319 rows x 81 columns]

# %%
train_df.query("OverallQual == 8").sort_values(by= "SalePrice")
# Maybe 770
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1349  1350          70       RM         50.0     5250   Pave  Pave      Reg
# 1324  1325          20       RL         75.0     9986   Pave   NaN      Reg
# 458    459          70       RM          NaN     5100   Pave  Grvl      Reg
# 1211  1212          50       RL        152.0    12134   Pave   NaN      IR1
# 991    992          70       RM        121.0    17671   Pave  Grvl      Reg
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 664    665          20       RL         49.0    20896   Pave   NaN      IR2
# 1142  1143          60       RL         77.0     9965   Pave   NaN      Reg
# 496    497          20       RL          NaN    12692   Pave   NaN      IR1
# 473    474          20       RL        110.0    14977   Pave   NaN      IR1
# 769    770          60       RL         47.0    53504   Pave   NaN      IR2
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 1349         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1324         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 458          Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 1211         Bnk    AllPub  ...        0    NaN    NaN         NaN       0
# 991          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# ...          ...       ...  ...      ...    ...    ...         ...     ...
# 664          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1142         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 496          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 473          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 769          HLS    AllPub  ...        0    NaN    NaN         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# 1349     12   2008        WD         Normal     122000
# 1324      2   2007       New        Partial     147000
# 458       6   2008        WD         Normal     161000
# 1211      6   2010        WD         Normal     164000
# 991      11   2009        WD         Normal     168000
# ...     ...    ...       ...            ...        ...
# 664       1   2006       New        Partial     423000
# 1142      4   2007       New        Partial     424870
# 496       5   2007        WD         Normal     430000
# 473       7   2007       New        Partial     440000
# 769       6   2010        WD         Normal     538000
#
# [168 rows x 81 columns]

# %%
train_df.query("OverallQual == 9").sort_values(by= "SalePrice")
# maybe 1047, 804, 899
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 963    964          20       RL        122.0    11923   Pave   NaN      IR1
# 765    766          20       RL         75.0    14587   Pave   NaN      IR1
# 343    344         120       RL         63.0     8849   Pave   NaN      IR1
# 34      35         120       RL         60.0     7313   Pave   NaN      Reg
# 683    684          20       RL         90.0    11248   Pave   NaN      IR1
# 610    611          60       RL          NaN    11050   Pave   NaN      Reg
# 618    619          20       RL         90.0    11694   Pave   NaN      Reg
# 1359  1360          20       RL        129.0    16737   Pave   NaN      Reg
# 540    541          20       RL         85.0    14601   Pave   NaN      Reg
# 1036  1037          20       RL         89.0    12898   Pave   NaN      IR1
# 350    351         120       RL         68.0     7820   Pave   NaN      IR1
# 45      46         120       RL         61.0     7658   Pave   NaN      Reg
# 932    933          20       RL         84.0    11670   Pave   NaN      IR1
# 724    725          20       RL         86.0    13286   Pave   NaN      IR1
# 1305  1306          20       RL        108.0    13173   Pave   NaN      IR1
# 566    567          60       RL         77.0    11198   Pave   NaN      IR1
# 480    481          20       RL         98.0    16033   Pave   NaN      IR1
# 885    886         120       FV         50.0     5119   Pave   NaN      IR1
# 1313  1314          60       RL        108.0    14774   Pave   NaN      IR1
# 1058  1059          60       RL         96.0    11308   Pave   NaN      IR1
# 320    321          60       RL        111.0    16259   Pave   NaN      Reg
# 11      12          60       RL         85.0    11924   Pave   NaN      IR1
# 877    878          60       RL         74.0     8834   Pave   NaN      Reg
# 309    310          20       RL         90.0    12378   Pave   NaN      IR1
# 1228  1229         120       RL         65.0     8769   Pave   NaN      Reg
# 644    645          20       FV         85.0     9187   Pave   NaN      Reg
# 481    482          20       RL         72.0    11846   Pave   NaN      IR1
# 336    337          20       RL         86.0    14157   Pave   NaN      IR1
# 1388  1389          20       RL         42.0    14892   Pave   NaN      IR1
# 1267  1268          20       RL         89.0    13214   Pave   NaN      IR1
# 477    478          60       RL        105.0    13693   Pave   NaN      Reg
# 53      54          20       RL         68.0    50271   Pave   NaN      IR1
# 378    379          20       RL         88.0    11394   Pave   NaN      Reg
# 987    988          20       RL         83.0    10159   Pave   NaN      IR1
# 161    162          60       RL        110.0    13688   Pave   NaN      IR1
# 278    279          20       RL        107.0    14450   Pave   NaN      Reg
# 349    350          60       RL         56.0    20431   Pave   NaN      IR2
# 527    528          60       RL         67.0    14948   Pave   NaN      IR1
# 798    799          60       RL        104.0    13518   Pave   NaN      Reg
# 178    179          20       RL         63.0    17423   Pave   NaN      IR1
# 1046  1047          60       RL         85.0    16056   Pave   NaN      IR1
# 803    804          60       RL        107.0    13891   Pave   NaN      Reg
# 898    899          20       RL        100.0    12919   Pave   NaN      IR1
#
#      LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal  \
# 963          Lvl    AllPub  ...        0    NaN   NaN         NaN       0
# 765          Lvl    AllPub  ...        0    NaN   NaN         NaN       0
# 343          Lvl    AllPub  ...        0    NaN   NaN         NaN       0
# 34           Lvl    AllPub  ...        0    NaN   NaN         NaN       0
# 683          Lvl    AllPub  ...        0    NaN   NaN         NaN       0
# 610          Lvl    AllPub  ...        0    NaN   NaN         NaN       0
# 618          Lvl    AllPub  ...        0    NaN   NaN         NaN       0
# 1359         Lvl    AllPub  ...        0    NaN   NaN         NaN       0
# 540          Lvl    AllPub  ...        0    NaN   NaN         NaN       0
# 1036         HLS    AllPub  ...        0    NaN   NaN         NaN       0
# 350          Lvl    AllPub  ...        0    NaN   NaN         NaN       0
# 45           Lvl    AllPub  ...        0    NaN   NaN         NaN       0
# 932          Lvl    AllPub  ...        0    NaN   NaN         NaN       0
# 724          Lvl    AllPub  ...        0    NaN   NaN         NaN       0
# 1305         Lvl    AllPub  ...        0    NaN   NaN         NaN       0
# 566          Lvl    AllPub  ...        0    NaN   NaN         NaN       0
# 480          Lvl    AllPub  ...        0    NaN   NaN         NaN       0
# 885          Lvl    AllPub  ...        0    NaN   NaN         NaN       0
# 1313         Lvl    AllPub  ...        0    NaN   NaN         NaN       0
# 1058         Lvl    AllPub  ...        0    NaN   NaN         NaN       0
# 320          Lvl    AllPub  ...        0    NaN   NaN         NaN       0
# 11           Lvl    AllPub  ...        0    NaN   NaN         NaN       0
# 877          Lvl    AllPub  ...        0    NaN   NaN         NaN       0
# 309          Lvl    AllPub  ...        0    NaN   NaN         NaN       0
# 1228         Lvl    AllPub  ...        0    NaN   NaN         NaN       0
# 644          Lvl    AllPub  ...        0    NaN   NaN         NaN       0
# 481          HLS    AllPub  ...        0    NaN   NaN         NaN       0
# 336          HLS    AllPub  ...        0    NaN   NaN         NaN       0
# 1388         HLS    AllPub  ...        0    NaN   NaN         NaN       0
# 1267         HLS    AllPub  ...        0    NaN   NaN         NaN       0
# 477          Lvl    AllPub  ...        0    NaN   NaN         NaN       0
# 53           Low    AllPub  ...        0    NaN   NaN         NaN       0
# 378          Lvl    AllPub  ...        0    NaN   NaN         NaN       0
# 987          Lvl    AllPub  ...        0    NaN   NaN         NaN       0
# 161          Lvl    AllPub  ...        0    NaN   NaN         NaN       0
# 278          Lvl    AllPub  ...        0    NaN   NaN         NaN       0
# 349          Lvl    AllPub  ...        0    NaN   NaN         NaN       0
# 527          Lvl    AllPub  ...        0    NaN   NaN         NaN       0
# 798          Lvl    AllPub  ...        0    NaN   NaN         NaN       0
# 178          Lvl    AllPub  ...        0    NaN   NaN         NaN       0
# 1046         Lvl    AllPub  ...        0    NaN   NaN         NaN       0
# 803          Lvl    AllPub  ...        0    NaN   NaN         NaN       0
# 898          Lvl    AllPub  ...        0    NaN   NaN         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# 963       5   2009        WD         Normal     239000
# 765       8   2008       New        Partial     264132
# 343       7   2008        WD         Normal     266000
# 34        8   2007        WD         Normal     277500
# 683       7   2007        WD         Normal     285000
# 610       5   2009        WD         Normal     313000
# 618       7   2007       New        Partial     314813
# 1359      9   2006        WD         Normal     315000
# 540       3   2009        WD         Normal     315000
# 1036      9   2009        WD         Normal     315500
# 350      12   2007       New        Partial     318061
# 45        2   2010        WD         Normal     319900
# 932       3   2007        WD         Normal     320000
# 724       2   2009        WD         Normal     320000
# 1305     11   2009        WD         Normal     325000
# 566       6   2008        WD         Normal     325000
# 480       3   2006        WD         Normal     326000
# 885       1   2008       CWD        Abnorml     328900
# 1313      5   2010        WD         Normal     333168
# 1058      7   2009        WD         Normal     335000
# 320       9   2006       New        Partial     342643
# 11        7   2006       New        Partial     345000
# 877       6   2009        WD         Normal     350000
# 309      11   2006        WD         Normal     360000
# 1228     10   2008       New        Partial     367294
# 644      10   2009       New        Partial     370878
# 481       8   2006        WD         Normal     374000
# 336       7   2007        WD         Normal     377426
# 1388     10   2009        WD         Normal     377500
# 1267      5   2010        WD         Normal     378500
# 477       3   2007        WD         Normal     380000
# 53       11   2006        WD         Normal     385000
# 378       6   2010       New        Partial     394432
# 987       4   2010       New        Partial     395192
# 161       3   2008        WD         Normal     412500
# 278       5   2007       New        Partial     415298
# 349       4   2006       New        Partial     437154
# 527      11   2008       New        Partial     446261
# 798       7   2009       New        Partial     485000
# 178       7   2009       New        Partial     501837
# 1046      7   2006       New        Partial     556581
# 803       1   2009       New        Partial     582933
# 898       3   2010       New        Partial     611657
#
# [43 rows x 81 columns]

# %%
plt.scatter(x='OverallCond', y='SalePrice', data=train_df)

# %%
train_df.query('OverallCond == 2').sort_values(by= "SalePrice")
#379
# Out:
#       Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 398  399          30       RM         60.0     8967   Pave   NaN      Reg
# 250  251          30       RL         55.0     5350   Pave   NaN      IR1
# 88    89          50  C (all)        105.0     8470   Pave   NaN      IR1
# 676  677          70       RM         60.0     9600   Pave  Grvl      Reg
# 378  379          20       RL         88.0    11394   Pave   NaN      Reg
#
#     LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 398         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 250         Lvl    AllPub  ...        0    NaN   GdWo        Shed     450
# 88          Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 676         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 378         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
#
#     MoSold YrSold  SaleType  SaleCondition  SalePrice
# 398     11   2007        WD        Abnorml      67000
# 250      5   2010        WD         Normal      76500
# 88      10   2009     ConLD        Abnorml      85000
# 676      5   2006        WD         Normal      87000
# 378      6   2010       New        Partial     394432
#
# [5 rows x 81 columns]

# %%
train_df.query('OverallCond == 5').sort_values(by= "SalePrice")
#1183
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 495    496          30  C (all)         60.0     7879   Pave   NaN      Reg
# 705    706         190       RM         70.0     5600   Pave   NaN      Reg
# 812    813          20  C (all)         66.0     8712   Grvl   NaN      Reg
# 1100  1101          30       RL         60.0     8400   Pave   NaN      Reg
# 462    463          20       RL         60.0     8281   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1046  1047          60       RL         85.0    16056   Pave   NaN      IR1
# 803    804          60       RL        107.0    13891   Pave   NaN      Reg
# 898    899          20       RL        100.0    12919   Pave   NaN      IR1
# 1169  1170          60       RL        118.0    35760   Pave   NaN      IR1
# 1182  1183          60       RL        160.0    15623   Pave   NaN      IR1
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 495          Lvl    AllPub  ...        0    NaN   GdWo         NaN       0
# 705          Lvl    AllPub  ...        0    NaN    NaN        Othr    3500
# 812          Bnk    AllPub  ...        0    NaN    NaN        Shed      54
# 1100         Bnk    AllPub  ...        0    NaN    NaN         NaN       0
# 462          Lvl    AllPub  ...        0    NaN   GdWo         NaN       0
# ...          ...       ...  ...      ...    ...    ...         ...     ...
# 1046         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 803          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 898          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1169         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1182         Lvl    AllPub  ...      555     Ex  MnPrv         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# 495      11   2009        WD        Abnorml      34900
# 705       7   2010        WD         Normal      55000
# 812       6   2010        WD         Alloca      55993
# 1100      1   2009        WD         Normal      60000
# 462      12   2009        WD         Normal      62383
# ...     ...    ...       ...            ...        ...
# 1046      7   2006       New        Partial     556581
# 803       1   2009       New        Partial     582933
# 898       3   2010       New        Partial     611657
# 1169      7   2006        WD         Normal     625000
# 1182      7   2007        WD        Abnorml     745000
#
# [821 rows x 81 columns]

# %%
train_df.query('OverallCond == 6 & SalePrice > 700000')
#692
# Out:
#       Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 691  692          60       RL        104.0    21535   Pave   NaN      IR1
#
#     LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal  \
# 691         Lvl    AllPub  ...        0    NaN   NaN         NaN       0
#
#     MoSold YrSold  SaleType  SaleCondition  SalePrice
# 691      1   2007        WD         Normal     755000
#
# [1 rows x 81 columns]

# %%
train_df.query('OverallCond == 9').sort_values(by= "SalePrice")
# 186
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 241    242          30       RM         40.0     3880   Pave   NaN      Reg
# 1123  1124          20       RL         50.0     9405   Pave   NaN      Reg
# 1327  1328          20       RL         60.0     6600   Pave   NaN      Reg
# 1352  1353          50       RM         50.0     6000   Pave   NaN      Reg
# 703    704         190       RM         76.0     7630   Pave   NaN      Reg
# 1149  1150          70       RM         50.0     9000   Pave   NaN      Reg
# 1213  1214          80       RL          NaN    10246   Pave   NaN      IR1
# 461    462          70       RL         60.0     7200   Pave   NaN      Reg
# 508    509          70       RM         60.0     9600   Pave   NaN      Reg
# 991    992          70       RM        121.0    17671   Pave  Grvl      Reg
# 1435  1436          20       RL         80.0     8400   Pave   NaN      Reg
# 980    981          85       RL          NaN    12122   Pave   NaN      IR1
# 191    192          60       RL          NaN     7472   Pave   NaN      IR1
# 726    727          20       RL          NaN    21695   Pave   NaN      IR1
# 519    520          70       RL         53.0    10918   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 304    305          75       RM         87.0    18386   Pave   NaN      Reg
# 745    746          60       RL          NaN     8963   Pave   NaN      IR1
# 218    219          50       RL          NaN    15660   Pave   NaN      IR1
# 583    584          75       RM         75.0    13500   Pave   NaN      Reg
# 1268  1269          50       RL          NaN    14100   Pave   NaN      IR1
# 185    186          75       RM         90.0    22950   Pave   NaN      IR2
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 241          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1123         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1327         Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 1352         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 703          Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 1149         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1213         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 461          Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 508          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 991          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1435         Lvl    AllPub  ...        0    NaN  GdPrv         NaN       0
# 980          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 191          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 726          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 519          Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 1457         Lvl    AllPub  ...        0    NaN  GdPrv        Shed    2500
# 304          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 745          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 218          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 583          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1268         Lvl    AllPub  ...        0    NaN   GdWo         NaN       0
# 185          Lvl    AllPub  ...        0    NaN  GdPrv         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# 241       8   2007        WD         Normal     110500
# 1123      6   2009        WD         Normal     118000
# 1327     10   2008        WD         Normal     130500
# 1352      7   2009        WD         Normal     134900
# 703       5   2010        WD         Normal     140000
# 1149      7   2009        WD         Normal     143000
# 1213      5   2006        WD         Normal     145000
# 461       4   2009        WD         Normal     155000
# 508      10   2008        WD         Normal     161000
# 991      11   2009        WD         Normal     168000
# 1435      7   2008       COD        Abnorml     174000
# 980       7   2008        WD         Normal     178400
# 191       6   2007        WD         Normal     184000
# 726      12   2009        WD         Normal     222000
# 519       6   2009        WD         Normal     234000
# 1457      5   2010        WD         Normal     266500
# 304       5   2008        WD         Normal     295000
# 745       7   2008        WD         Normal     299800
# 218       5   2008        WD         Normal     311500
# 583       7   2008        WD         Normal     325000
# 1268      5   2008        WD         Normal     381000
# 185       6   2006        WD         Normal     475000
#
# [22 rows x 81 columns]

# %%
plt.scatter(x='YearBuilt', y='SalePrice', data=train_df)

# %%
train_df.query('YearBuilt < 1900 & SalePrice > 200000')
#186, 305, 584, 748
# Out:
#       Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 185  186          75       RM         90.0    22950   Pave   NaN      IR2
# 304  305          75       RM         87.0    18386   Pave   NaN      Reg
# 583  584          75       RM         75.0    13500   Pave   NaN      Reg
# 747  748          70       RM         65.0    11700   Pave  Pave      IR1
#
#     LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 185         Lvl    AllPub  ...        0    NaN  GdPrv         NaN       0
# 304         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 583         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 747         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
#
#     MoSold YrSold  SaleType  SaleCondition  SalePrice
# 185      6   2006        WD         Normal     475000
# 304      5   2008        WD         Normal     295000
# 583      7   2008        WD         Normal     325000
# 747      5   2009        WD         Normal     265979
#
# [4 rows x 81 columns]

# %%
train_df.query('YearBuilt > 1980 & SalePrice > 500000')
# 441, 692, 770, 804, 770, 804, 899, 1047, 1170, 1183
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 178    179          20       RL         63.0    17423   Pave   NaN      IR1
# 440    441          20       RL        105.0    15431   Pave   NaN      Reg
# 691    692          60       RL        104.0    21535   Pave   NaN      IR1
# 769    770          60       RL         47.0    53504   Pave   NaN      IR2
# 803    804          60       RL        107.0    13891   Pave   NaN      Reg
# 898    899          20       RL        100.0    12919   Pave   NaN      IR1
# 1046  1047          60       RL         85.0    16056   Pave   NaN      IR1
# 1169  1170          60       RL        118.0    35760   Pave   NaN      IR1
# 1182  1183          60       RL        160.0    15623   Pave   NaN      IR1
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 178          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 440          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 691          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 769          HLS    AllPub  ...        0    NaN    NaN         NaN       0
# 803          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 898          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1046         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1169         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1182         Lvl    AllPub  ...      555     Ex  MnPrv         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# 178       7   2009       New        Partial     501837
# 440       4   2009        WD         Normal     555000
# 691       1   2007        WD         Normal     755000
# 769       6   2010        WD         Normal     538000
# 803       1   2009       New        Partial     582933
# 898       3   2010       New        Partial     611657
# 1046      7   2006       New        Partial     556581
# 1169      7   2006        WD         Normal     625000
# 1182      7   2007        WD        Abnorml     745000
#
# [9 rows x 81 columns]

# %%
plt.scatter(x='YearRemodAdd', y='SalePrice', data=train_df)

# %%
train_df.query('YearRemodAdd < 1970 & SalePrice > 300000')
#314
# Out:
#       Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 313  314          20       RL        150.0   215245   Pave   NaN      IR3
#
#     LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal  \
# 313         Low    AllPub  ...        0    NaN   NaN         NaN       0
#
#     MoSold YrSold  SaleType  SaleCondition  SalePrice
# 313      6   2009        WD         Normal     375000
#
# [1 rows x 81 columns]

# %%
train_df.query('YearRemodAdd > 1990 & SalePrice > 500000')
# 441, 692, 770, 804, 899, 1047, 1170, 1183
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 178    179          20       RL         63.0    17423   Pave   NaN      IR1
# 440    441          20       RL        105.0    15431   Pave   NaN      Reg
# 691    692          60       RL        104.0    21535   Pave   NaN      IR1
# 769    770          60       RL         47.0    53504   Pave   NaN      IR2
# 803    804          60       RL        107.0    13891   Pave   NaN      Reg
# 898    899          20       RL        100.0    12919   Pave   NaN      IR1
# 1046  1047          60       RL         85.0    16056   Pave   NaN      IR1
# 1169  1170          60       RL        118.0    35760   Pave   NaN      IR1
# 1182  1183          60       RL        160.0    15623   Pave   NaN      IR1
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 178          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 440          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 691          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 769          HLS    AllPub  ...        0    NaN    NaN         NaN       0
# 803          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 898          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1046         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1169         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1182         Lvl    AllPub  ...      555     Ex  MnPrv         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# 178       7   2009       New        Partial     501837
# 440       4   2009        WD         Normal     555000
# 691       1   2007        WD         Normal     755000
# 769       6   2010        WD         Normal     538000
# 803       1   2009       New        Partial     582933
# 898       3   2010       New        Partial     611657
# 1046      7   2006       New        Partial     556581
# 1169      7   2006        WD         Normal     625000
# 1182      7   2007        WD        Abnorml     745000
#
# [9 rows x 81 columns]

# %%
plt.scatter(x='MasVnrArea', y='SalePrice', data=train_df)

# %%
train_df.query('MasVnrArea > 1500')
#298
# Out:
#       Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 297  298          60       FV         66.0     7399   Pave  Pave      IR1
#
#     LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal  \
# 297         Lvl    AllPub  ...        0    NaN   NaN         NaN       0
#
#     MoSold YrSold  SaleType  SaleCondition  SalePrice
# 297      6   2007        WD         Normal     239000
#
# [1 rows x 81 columns]

# %%
train_df.query('MasVnrArea == 0').sort_values(by= "SalePrice")
# 1183
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 495    496          30  C (all)         60.0     7879   Pave   NaN      Reg
# 916    917          20  C (all)         50.0     9000   Pave   NaN      Reg
# 968    969          50       RM         50.0     5925   Pave   NaN      Reg
# 533    534          20       RL         50.0     5000   Pave   NaN      Reg
# 30      31          70  C (all)         50.0     8500   Pave  Pave      Reg
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 688    689          20       RL         60.0     8089   Pave   NaN      Reg
# 664    665          20       RL         49.0    20896   Pave   NaN      IR2
# 496    497          20       RL          NaN    12692   Pave   NaN      IR1
# 185    186          75       RM         90.0    22950   Pave   NaN      IR2
# 1182  1183          60       RL        160.0    15623   Pave   NaN      IR1
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 495          Lvl    AllPub  ...        0    NaN   GdWo         NaN       0
# 916          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 968          Lvl    AllPub  ...        0    NaN   GdWo         NaN       0
# 533          Low    AllPub  ...        0    NaN    NaN         NaN       0
# 30           Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# ...          ...       ...  ...      ...    ...    ...         ...     ...
# 688          HLS    AllPub  ...        0    NaN    NaN         NaN       0
# 664          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 496          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 185          Lvl    AllPub  ...        0    NaN  GdPrv         NaN       0
# 1182         Lvl    AllPub  ...      555     Ex  MnPrv         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# 495      11   2009        WD        Abnorml      34900
# 916      10   2006        WD        Abnorml      35311
# 968       5   2009        WD        Abnorml      37900
# 533       1   2007        WD         Normal      39300
# 30        7   2008        WD         Normal      40000
# ...     ...    ...       ...            ...        ...
# 688      10   2007       New        Partial     392000
# 664       1   2006       New        Partial     423000
# 496       5   2007        WD         Normal     430000
# 185       6   2006        WD         Normal     475000
# 1182      7   2007        WD        Abnorml     745000
#
# [861 rows x 81 columns]

# %%
train_df.query('MasVnrArea > 200 & MasVnrArea < 800 & SalePrice > 500000').sort_values(by= "SalePrice")
# 770, 1047, 804, 899
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 178    179          20       RL         63.0    17423   Pave   NaN      IR1
# 769    770          60       RL         47.0    53504   Pave   NaN      IR2
# 1046  1047          60       RL         85.0    16056   Pave   NaN      IR1
# 803    804          60       RL        107.0    13891   Pave   NaN      Reg
# 898    899          20       RL        100.0    12919   Pave   NaN      IR1
#
#      LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal  \
# 178          Lvl    AllPub  ...        0    NaN   NaN         NaN       0
# 769          HLS    AllPub  ...        0    NaN   NaN         NaN       0
# 1046         Lvl    AllPub  ...        0    NaN   NaN         NaN       0
# 803          Lvl    AllPub  ...        0    NaN   NaN         NaN       0
# 898          Lvl    AllPub  ...        0    NaN   NaN         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# 178       7   2009       New        Partial     501837
# 769       6   2010        WD         Normal     538000
# 1046      7   2006       New        Partial     556581
# 803       1   2009       New        Partial     582933
# 898       3   2010       New        Partial     611657
#
# [5 rows x 81 columns]

# %%
plt.scatter(x='BsmtFinSF1', y='SalePrice', data=train_df)

# %%
train_df.query('BsmtFinSF1 > 5000')
#1299
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1298  1299          60       RL        313.0    63887   Pave   NaN      IR3
#
#      LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal  \
# 1298         Bnk    AllPub  ...      480     Gd   NaN         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# 1298      1   2008       New        Partial     160000
#
# [1 rows x 81 columns]

# %%
train_df.query('BsmtFinSF1 < 3000 & SalePrice > 500000')
# 441, 692, 770, 804, 899, 1047, 1170, 1183
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 178    179          20       RL         63.0    17423   Pave   NaN      IR1
# 440    441          20       RL        105.0    15431   Pave   NaN      Reg
# 691    692          60       RL        104.0    21535   Pave   NaN      IR1
# 769    770          60       RL         47.0    53504   Pave   NaN      IR2
# 803    804          60       RL        107.0    13891   Pave   NaN      Reg
# 898    899          20       RL        100.0    12919   Pave   NaN      IR1
# 1046  1047          60       RL         85.0    16056   Pave   NaN      IR1
# 1169  1170          60       RL        118.0    35760   Pave   NaN      IR1
# 1182  1183          60       RL        160.0    15623   Pave   NaN      IR1
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 178          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 440          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 691          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 769          HLS    AllPub  ...        0    NaN    NaN         NaN       0
# 803          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 898          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1046         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1169         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1182         Lvl    AllPub  ...      555     Ex  MnPrv         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# 178       7   2009       New        Partial     501837
# 440       4   2009        WD         Normal     555000
# 691       1   2007        WD         Normal     755000
# 769       6   2010        WD         Normal     538000
# 803       1   2009       New        Partial     582933
# 898       3   2010       New        Partial     611657
# 1046      7   2006       New        Partial     556581
# 1169      7   2006        WD         Normal     625000
# 1182      7   2007        WD        Abnorml     745000
#
# [9 rows x 81 columns]

# %%
plt.scatter(x='BsmtFinSF2', y='SalePrice', data=train_df)

# %%
train_df.query('BsmtFinSF2 > 200 & SalePrice > 310000')
#441, 314
# Out:
#       Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 313  314          20       RL        150.0   215245   Pave   NaN      IR3
# 440  441          20       RL        105.0    15431   Pave   NaN      Reg
#
#     LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal  \
# 313         Low    AllPub  ...        0    NaN   NaN         NaN       0
# 440         Lvl    AllPub  ...        0    NaN   NaN         NaN       0
#
#     MoSold YrSold  SaleType  SaleCondition  SalePrice
# 313      6   2009        WD         Normal     375000
# 440      4   2009        WD         Normal     555000
#
# [2 rows x 81 columns]

# %%
train_df.query('BsmtFinSF2 > 1400')
# 323
# Out:
#       Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 322  323          60       RL         86.0    10380   Pave   NaN      IR1
#
#     LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 322         Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
#
#     MoSold YrSold  SaleType  SaleCondition  SalePrice
# 322      8   2007        WD         Normal     301000
#
# [1 rows x 81 columns]

# %%
train_df.query('BsmtFinSF2 == 0 & SalePrice > 700000')
# 692, 1183
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 691    692          60       RL        104.0    21535   Pave   NaN      IR1
# 1182  1183          60       RL        160.0    15623   Pave   NaN      IR1
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 691          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1182         Lvl    AllPub  ...      555     Ex  MnPrv         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# 691       1   2007        WD         Normal     755000
# 1182      7   2007        WD        Abnorml     745000
#
# [2 rows x 81 columns]

# %%
plt.scatter(x='BsmtUnfSF', y='SalePrice', data=train_df)

# %%
train_df.query("BsmtUnfSF > 0 & SalePrice > 500000")
# 179, 441, 692, 770, 804, 899, 1047, 1170, 1183
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 178    179          20       RL         63.0    17423   Pave   NaN      IR1
# 440    441          20       RL        105.0    15431   Pave   NaN      Reg
# 691    692          60       RL        104.0    21535   Pave   NaN      IR1
# 769    770          60       RL         47.0    53504   Pave   NaN      IR2
# 803    804          60       RL        107.0    13891   Pave   NaN      Reg
# 898    899          20       RL        100.0    12919   Pave   NaN      IR1
# 1046  1047          60       RL         85.0    16056   Pave   NaN      IR1
# 1169  1170          60       RL        118.0    35760   Pave   NaN      IR1
# 1182  1183          60       RL        160.0    15623   Pave   NaN      IR1
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 178          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 440          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 691          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 769          HLS    AllPub  ...        0    NaN    NaN         NaN       0
# 803          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 898          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1046         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1169         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1182         Lvl    AllPub  ...      555     Ex  MnPrv         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# 178       7   2009       New        Partial     501837
# 440       4   2009        WD         Normal     555000
# 691       1   2007        WD         Normal     755000
# 769       6   2010        WD         Normal     538000
# 803       1   2009       New        Partial     582933
# 898       3   2010       New        Partial     611657
# 1046      7   2006       New        Partial     556581
# 1169      7   2006        WD         Normal     625000
# 1182      7   2007        WD        Abnorml     745000
#
# [9 rows x 81 columns]

# %%
plt.scatter(x='TotalBsmtSF', y='SalePrice', data=train_df)

# %%
train_df.query('TotalBsmtSF > 5000')
#1299
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1298  1299          60       RL        313.0    63887   Pave   NaN      IR3
#
#      LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal  \
# 1298         Bnk    AllPub  ...      480     Gd   NaN         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# 1298      1   2008       New        Partial     160000
#
# [1 rows x 81 columns]

# %%
train_df.query("TotalBsmtSF > 2000 & SalePrice > 700000")
# 692, 1183
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 691    692          60       RL        104.0    21535   Pave   NaN      IR1
# 1182  1183          60       RL        160.0    15623   Pave   NaN      IR1
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 691          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1182         Lvl    AllPub  ...      555     Ex  MnPrv         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# 691       1   2007        WD         Normal     755000
# 1182      7   2007        WD        Abnorml     745000
#
# [2 rows x 81 columns]

# %%
plt.scatter(x='1stFlrSF', y='SalePrice', data=train_df)

# %%
train_df.query("`1stFlrSF` > 0 & SalePrice > 700000")
# 692, 1183
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 691    692          60       RL        104.0    21535   Pave   NaN      IR1
# 1182  1183          60       RL        160.0    15623   Pave   NaN      IR1
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 691          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1182         Lvl    AllPub  ...      555     Ex  MnPrv         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# 691       1   2007        WD         Normal     755000
# 1182      7   2007        WD        Abnorml     745000
#
# [2 rows x 81 columns]

# %%
train_df.query("`1stFlrSF` > 4000")
# 1299
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1298  1299          60       RL        313.0    63887   Pave   NaN      IR3
#
#      LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal  \
# 1298         Bnk    AllPub  ...      480     Gd   NaN         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# 1298      1   2008       New        Partial     160000
#
# [1 rows x 81 columns]

# %%
plt.scatter(x='2ndFlrSF', y='SalePrice', data=train_df)

# %%
train_df.query("`2ndFlrSF` > 0 & SalePrice > 500000")
# 692, 770, 804, 1047, 1170, 1183
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 691    692          60       RL        104.0    21535   Pave   NaN      IR1
# 769    770          60       RL         47.0    53504   Pave   NaN      IR2
# 803    804          60       RL        107.0    13891   Pave   NaN      Reg
# 1046  1047          60       RL         85.0    16056   Pave   NaN      IR1
# 1169  1170          60       RL        118.0    35760   Pave   NaN      IR1
# 1182  1183          60       RL        160.0    15623   Pave   NaN      IR1
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 691          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 769          HLS    AllPub  ...        0    NaN    NaN         NaN       0
# 803          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1046         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1169         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1182         Lvl    AllPub  ...      555     Ex  MnPrv         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# 691       1   2007        WD         Normal     755000
# 769       6   2010        WD         Normal     538000
# 803       1   2009       New        Partial     582933
# 1046      7   2006       New        Partial     556581
# 1169      7   2006        WD         Normal     625000
# 1182      7   2007        WD        Abnorml     745000
#
# [6 rows x 81 columns]

# %%
plt.scatter(x='LowQualFinSF', y='SalePrice', data=train_df)

# %%
train_df.query('LowQualFinSF > 500')
#186
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 88      89          50  C (all)        105.0     8470   Pave   NaN      IR1
# 170    171          50       RM          NaN    12358   Pave   NaN      IR1
# 185    186          75       RM         90.0    22950   Pave   NaN      IR2
# 635    636         190       RH         60.0    10896   Pave  Pave      Reg
# 1009  1010          50       RL         60.0     6000   Pave   NaN      Reg
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 88           Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 170          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 185          Lvl    AllPub  ...        0    NaN  GdPrv         NaN       0
# 635          Bnk    AllPub  ...        0    NaN    NaN         NaN       0
# 1009         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# 88       10   2009     ConLD        Abnorml      85000
# 170       5   2007        WD         Normal     128500
# 185       6   2006        WD         Normal     475000
# 635       3   2007        WD        Abnorml     200000
# 1009      6   2006        WD         Normal     102000
#
# [5 rows x 81 columns]

# %%
plt.scatter(x='GrLivArea', y='SalePrice', data=train_df)

# %%
train_df.query('GrLivArea > 4000')
#524, 1299, 1183, 692
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 523    524          60       RL        130.0    40094   Pave   NaN      IR1
# 691    692          60       RL        104.0    21535   Pave   NaN      IR1
# 1182  1183          60       RL        160.0    15623   Pave   NaN      IR1
# 1298  1299          60       RL        313.0    63887   Pave   NaN      IR3
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 523          Bnk    AllPub  ...        0    NaN    NaN         NaN       0
# 691          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1182         Lvl    AllPub  ...      555     Ex  MnPrv         NaN       0
# 1298         Bnk    AllPub  ...      480     Gd    NaN         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# 523      10   2007       New        Partial     184750
# 691       1   2007        WD         Normal     755000
# 1182      7   2007        WD        Abnorml     745000
# 1298      1   2008       New        Partial     160000
#
# [4 rows x 81 columns]

# %%
plt.scatter(x='BsmtFullBath', y='SalePrice', data=train_df)

# %%
train_df.query('BsmtFullBath == 3')
#739
# Out:
#       Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 738  739          90       RL         60.0    10800   Pave   NaN      Reg
#
#     LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal  \
# 738         Lvl    AllPub  ...        0    NaN   NaN         NaN       0
#
#     MoSold YrSold  SaleType  SaleCondition  SalePrice
# 738      3   2009        WD         Alloca     179000
#
# [1 rows x 81 columns]

# %%
plt.scatter(x='BsmtHalfBath', y='SalePrice', data=train_df)

# %%
train_df.query("BsmtHalfBath & SalePrice > 700000")
# 692
# Out:
#       Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 691  692          60       RL        104.0    21535   Pave   NaN      IR1
#
#     LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal  \
# 691         Lvl    AllPub  ...        0    NaN   NaN         NaN       0
#
#     MoSold YrSold  SaleType  SaleCondition  SalePrice
# 691      1   2007        WD         Normal     755000
#
# [1 rows x 81 columns]

# %%
stats.zscore(train_df['BsmtHalfBath']).unique()
# Out:
# array([-0.24106104,  3.94880935,  8.13867973])

# %%
train_df.query('BsmtHalfBath == 2')
#598, 955
# Out:
#       Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 597  598         120       RL         53.0     3922   Pave   NaN      Reg
# 954  955          90       RL         35.0     9400   Pave   NaN      IR1
#
#     LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal  \
# 597         Lvl    AllPub  ...        0    NaN   NaN         NaN       0
# 954         Lvl    AllPub  ...        0    NaN   NaN         NaN       0
#
#     MoSold YrSold  SaleType  SaleCondition  SalePrice
# 597      2   2007       New        Partial     194201
# 954     10   2006        WD        AdjLand     127500
#
# [2 rows x 81 columns]

# %%
plt.scatter(x='FullBath', y='SalePrice', data=train_df)

# %%
plt.scatter(x='HalfBath', y='SalePrice', data=train_df)

# %%
plt.scatter(x='BedroomAbvGr', y='SalePrice', data=train_df)

# %%
train_df.query('BedroomAbvGr == 8')
#636
# Out:
#       Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 635  636         190       RH         60.0    10896   Pave  Pave      Reg
#
#     LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal  \
# 635         Bnk    AllPub  ...        0    NaN   NaN         NaN       0
#
#     MoSold YrSold  SaleType  SaleCondition  SalePrice
# 635      3   2007        WD        Abnorml     200000
#
# [1 rows x 81 columns]

# %%
plt.scatter(x='KitchenAbvGr', y='SalePrice', data=train_df)

# %%
train_df.query('KitchenAbvGr == 3')
#49, 810
# Out:
#       Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 48    49         190       RM         33.0     4456   Pave   NaN      Reg
# 809  810          75       RM         90.0     8100   Pave   NaN      Reg
#
#     LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 48          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 809         Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
#
#     MoSold YrSold  SaleType  SaleCondition  SalePrice
# 48       6   2009       New        Partial     113000
# 809     11   2009        WD         Normal     106000
#
# [2 rows x 81 columns]

# %%
train_df.query('KitchenAbvGr == 0')
# 955
# Out:
#       Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 954  955          90       RL         35.0     9400   Pave   NaN      IR1
#
#     LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal  \
# 954         Lvl    AllPub  ...        0    NaN   NaN         NaN       0
#
#     MoSold YrSold  SaleType  SaleCondition  SalePrice
# 954     10   2006        WD        AdjLand     127500
#
# [1 rows x 81 columns]

# %%
plt.scatter(x='TotRmsAbvGrd', y='SalePrice', data=train_df)

# %%
train_df.query('TotRmsAbvGrd == 14')
#636
# Out:
#       Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 635  636         190       RH         60.0    10896   Pave  Pave      Reg
#
#     LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal  \
# 635         Bnk    AllPub  ...        0    NaN   NaN         NaN       0
#
#     MoSold YrSold  SaleType  SaleCondition  SalePrice
# 635      3   2007        WD        Abnorml     200000
#
# [1 rows x 81 columns]

# %%
train_df.query('TotRmsAbvGrd == 2')
# 534
# Out:
#       Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 533  534          20       RL         50.0     5000   Pave   NaN      Reg
#
#     LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal  \
# 533         Low    AllPub  ...        0    NaN   NaN         NaN       0
#
#     MoSold YrSold  SaleType  SaleCondition  SalePrice
# 533      1   2007        WD         Normal      39300
#
# [1 rows x 81 columns]

# %%
plt.scatter(x='Fireplaces', y='SalePrice', data=train_df)

# %%
train_df.query('Fireplaces == 3.0')
# 310, 643
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 166    167          20       RL          NaN    10708   Pave   NaN      IR1
# 309    310          20       RL         90.0    12378   Pave   NaN      IR1
# 605    606          60       RL         85.0    13600   Pave   NaN      Reg
# 642    643          80       RL         75.0    13860   Pave   NaN      Reg
# 1298  1299          60       RL        313.0    63887   Pave   NaN      IR3
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 166          Lvl    AllPub  ...        0    NaN   GdWo         NaN       0
# 309          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 605          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 642          Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 1298         Bnk    AllPub  ...      480     Gd    NaN         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# 166      11   2009       COD         Normal     190000
# 309      11   2006        WD         Normal     360000
# 605      10   2009        WD         Normal     205000
# 642       7   2009        WD         Normal     345000
# 1298      1   2008       New        Partial     160000
#
# [5 rows x 81 columns]

# %%
plt.scatter(x='GarageYrBlt', y='SalePrice', data=train_df)

# %%
plt.scatter(x='GarageCars', y='SalePrice', data=train_df)

# %%
plt.scatter(x='GarageArea', y='SalePrice', data=train_df)

# %%
train_df.query('GarageArea > 1200')
#1062, 1191, 582, 826, 1299
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 581    582          20       RL         98.0    12704   Pave   NaN      Reg
# 825    826          20       RL        114.0    14803   Pave   NaN      Reg
# 1061  1062          30  C (all)        120.0    18000   Grvl   NaN      Reg
# 1190  1191         190       RL          NaN    32463   Pave   NaN      Reg
# 1298  1299          60       RL        313.0    63887   Pave   NaN      IR3
#
#      LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal  \
# 581          Lvl    AllPub  ...        0    NaN   NaN         NaN       0
# 825          Lvl    AllPub  ...        0    NaN   NaN         NaN       0
# 1061         Low    AllPub  ...        0    NaN   NaN        Shed     560
# 1190         Low    AllPub  ...        0    NaN   NaN         NaN       0
# 1298         Bnk    AllPub  ...      480     Gd   NaN         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# 581       8   2009       New        Partial     253293
# 825       6   2008       New        Partial     385000
# 1061      8   2008     ConLD         Normal      81000
# 1190      3   2007        WD         Normal     168000
# 1298      1   2008       New        Partial     160000
#
# [5 rows x 81 columns]

# %%
plt.scatter(x='WoodDeckSF', y='SalePrice', data=train_df)

# %%
train_df.query("WoodDeckSF > 800")
# 54
# Out:
#     Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 53  54          20       RL         68.0    50271   Pave   NaN      IR1
#
#    LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal  \
# 53         Low    AllPub  ...        0    NaN   NaN         NaN       0
#
#    MoSold YrSold  SaleType  SaleCondition  SalePrice
# 53     11   2006        WD         Normal     385000
#
# [1 rows x 81 columns]

# %%
plt.scatter(x='OpenPorchSF', y='SalePrice', data=train_df)

# %%
train_df.query('OpenPorchSF > 500')
#496, 584, 1329
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 495    496          30  C (all)         60.0     7879   Pave   NaN      Reg
# 583    584          75       RM         75.0    13500   Pave   NaN      Reg
# 1328  1329          50       RM         60.0    10440   Pave  Grvl      Reg
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 495          Lvl    AllPub  ...        0    NaN   GdWo         NaN       0
# 583          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1328         Lvl    AllPub  ...        0    NaN  MnPrv        Shed    1150
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# 495      11   2009        WD        Abnorml      34900
# 583       7   2008        WD         Normal     325000
# 1328      6   2008        WD         Normal     256000
#
# [3 rows x 81 columns]

# %%
plt.scatter(x='EnclosedPorch', y='SalePrice', data=train_df)

# %%
train_df.query('EnclosedPorch > 500')
#198
# Out:
#       Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 197  198          75       RL        174.0    25419   Pave   NaN      Reg
#
#     LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 197         Lvl    AllPub  ...      512     Ex  GdPrv         NaN       0
#
#     MoSold YrSold  SaleType  SaleCondition  SalePrice
# 197      3   2006        WD        Abnorml     235000
#
# [1 rows x 81 columns]

# %%
plt.scatter(x='3SsnPorch', y='SalePrice', data=train_df)

# %%
plt.scatter(x='ScreenPorch', y='SalePrice', data=train_df)

# %%
train_df.query('ScreenPorch > 100 & ScreenPorch < 300 & SalePrice > 500000')
# 441, 770, 804
# Out:
#       Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 440  441          20       RL        105.0    15431   Pave   NaN      Reg
# 769  770          60       RL         47.0    53504   Pave   NaN      IR2
# 803  804          60       RL        107.0    13891   Pave   NaN      Reg
#
#     LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal  \
# 440         Lvl    AllPub  ...        0    NaN   NaN         NaN       0
# 769         HLS    AllPub  ...        0    NaN   NaN         NaN       0
# 803         Lvl    AllPub  ...        0    NaN   NaN         NaN       0
#
#     MoSold YrSold  SaleType  SaleCondition  SalePrice
# 440      4   2009        WD         Normal     555000
# 769      6   2010        WD         Normal     538000
# 803      1   2009       New        Partial     582933
#
# [3 rows x 81 columns]

# %%
plt.scatter(x='PoolArea', y='SalePrice', data=train_df)

# %%
values = [598, 955, 935, 1299, 250, 314, 336, 707, 379, 1183, 692, 441, 186, 524, 739, 636, 1062, 1191, 496, 198, 1338, 305, 584, 748, 770, 804, 899, 1047, 1170, 298, 323, 179, 49, 810, 534, 310, 643, 582, 826, 54, 1329, 198]

# %%
train_df = train_df[train_df.Id.isin(values) == False]

# %%
pd.DataFrame(train_df.isnull().sum().sort_values(ascending=False)).head(20)
# Out:
#                  0
# PoolQC        1415
# MiscFeature   1369
# Alley         1333
# Fence         1146
# MasVnrType     851
# FireplaceQu    681
# LotFrontage    255
# GarageYrBlt     74
# GarageCond      74
# GarageType      74
# GarageFinish    74
# GarageQual      74
# BsmtFinType2    37
# BsmtExposure    37
# BsmtQual        36
# BsmtCond        36
# BsmtFinType1    36
# MasVnrArea       8
# Electrical       1
# Id               0

# %%
train_df['MiscFeature'].unique()
# Out:
# array([nan, 'Shed', 'Gar2', 'Othr', 'TenC'], dtype=object)

# %%
train_df['Alley'].unique()
# Out:
# array([nan, 'Grvl', 'Pave'], dtype=object)

# %%
train_df['Alley'].fillna('No', inplace=True)
test_df['Alley'].fillna('No', inplace=True)

# %%
sns.catplot(data=train_df, x="Alley", y="SalePrice", kind="box")
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
train_df['Fence'].unique()
# Out:
# array([nan, 'MnPrv', 'GdWo', 'GdPrv', 'MnWw'], dtype=object)

# %%
train_df['Fence'].fillna('No', inplace=True)
test_df['Fence'].fillna('No', inplace=True)

# %%
sns.catplot(data=train_df, x="Fence", y="SalePrice", kind="box")
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
train_df['MasVnrType'].unique()
# Out:
# array(['BrkFace', nan, 'Stone', 'BrkCmn'], dtype=object)

# %%
train_df['MasVnrType'].fillna('No', inplace=True)
test_df['MasVnrType'].fillna('No', inplace=True)

# %%
sns.catplot(data=train_df, x="MasVnrType", y="SalePrice", kind="box")
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
train_df['MasVnrArea'].fillna(0, inplace=True)
test_df['MasVnrArea'].fillna(0, inplace=True)

# %%
train_df['FireplaceQu'].unique()
# Out:
# array([nan, 'TA', 'Gd', 'Fa', 'Ex', 'Po'], dtype=object)

# %%
train_df['FireplaceQu'].fillna('No', inplace=True)
test_df['FireplaceQu'].fillna('No', inplace=True)

# %%
sns.catplot(data=train_df, x="FireplaceQu", y="SalePrice", kind="box")
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.catplot(data=train_df, x="Fireplaces", y="SalePrice", kind="box")
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
train_df['LotFrontage'].fillna(0, inplace=True)
test_df['LotFrontage'].fillna(0, inplace=True)

# %%
train_df['GarageYrBlt'].corr(train_df['YearBuilt'])
# Out:
# 0.8359960996471276

# %%
train_df['GarageCond'].unique()
# Out:
# array(['TA', 'Fa', nan, 'Gd', 'Po', 'Ex'], dtype=object)

# %%
train_df['GarageCond'].fillna('No', inplace=True)
test_df['GarageCond'].fillna('No', inplace=True)

# %%
sns.catplot(data=train_df, x="GarageCond", y="SalePrice", kind="box")
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
train_df['GarageType'].fillna('No', inplace=True)
test_df['GarageType'].fillna('No', inplace=True)

# %%
sns.catplot(data=train_df, x="GarageType", y="SalePrice", kind="box")
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
train_df['GarageFinish'].fillna('No', inplace=True)
test_df['GarageFinish'].fillna('No', inplace=True)

# %%
sns.catplot(data=train_df, x="GarageFinish", y="SalePrice", kind="box")
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
train_df['GarageQual'].fillna('No', inplace=True)
test_df['GarageQual'].fillna('No', inplace=True)

# %%
sns.catplot(data=train_df, x="GarageQual", y="SalePrice", kind="box")
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
train_df['BsmtFinType2'].unique()
# Out:
# array(['Unf', 'BLQ', nan, 'ALQ', 'Rec', 'LwQ', 'GLQ'], dtype=object)

# %%
train_df['BsmtFinType2'].fillna('Unf', inplace=True)
test_df['BsmtFinType2'].fillna('Unf', inplace=True)

# %%
sns.catplot(data=train_df, x="BsmtFinType2", y="SalePrice", kind="box")
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
train_df['BsmtExposure'].unique()
# Out:
# array(['No', 'Gd', 'Mn', 'Av', nan], dtype=object)

# %%
train_df['BsmtExposure'].fillna('No', inplace=True)
test_df['BsmtExposure'].fillna('No', inplace=True)

# %%
sns.catplot(data=train_df, x="BsmtExposure", y="SalePrice", kind="box")
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
train_df['BsmtQual'].unique()
# Out:
# array(['Gd', 'TA', 'Ex', nan, 'Fa'], dtype=object)

# %%
train_df['BsmtQual'].fillna('No', inplace=True)
test_df['BsmtQual'].fillna('No', inplace=True)

# %%
sns.catplot(data=train_df, x="BsmtQual", y="SalePrice", kind="box")
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
train_df['BsmtCond'].unique()
# Out:
# array(['TA', 'Gd', nan, 'Fa', 'Po'], dtype=object)

# %%
train_df['BsmtCond'].fillna('No', inplace=True)
test_df['BsmtCond'].fillna('No', inplace=True)

# %%
sns.catplot(data=train_df, x="BsmtCond", y="SalePrice", kind="box")
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
train_df['BsmtFinType1'].unique()
# Out:
# array(['GLQ', 'ALQ', 'Unf', 'Rec', 'BLQ', nan, 'LwQ'], dtype=object)

# %%
train_df['BsmtFinType1'].fillna('Unf', inplace=True)
test_df['BsmtFinType1'].fillna('Unf', inplace=True)

# %%
sns.catplot(data=train_df, x="BsmtFinType1", y="SalePrice", kind="box")
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
train_df['MasVnrArea'].fillna(0, inplace=True)
test_df['MasVnrArea'].fillna(0, inplace=True)

# %%
train_df['Electrical'].fillna('SBrkr', inplace=True)
test_df['Electrical'].fillna('SBrkr', inplace=True)

# %%
train_df = train_df.drop(columns=['PoolQC', 'MiscFeature', 'Alley', 'Fence', 'GarageYrBlt', 'GarageCond', 'BsmtFinType2'])
test_df = test_df.drop(columns=['PoolQC', 'MiscFeature', 'Alley', 'Fence', 'GarageYrBlt', 'GarageCond', 'BsmtFinType2'])

# %%
#feature engineering

# %%
train_df['houseage'] = train_df['YrSold'] - train_df['YearBuilt']
test_df['houseage'] = test_df['YrSold'] - test_df['YearBuilt']

# %%
train_df['houseremodelage'] = train_df['YrSold'] - train_df['YearRemodAdd']
test_df['houseremodelage'] = test_df['YrSold'] - test_df['YearRemodAdd']

# %%
train_df['totalsf'] = train_df['1stFlrSF'] + train_df['2ndFlrSF'] + train_df['BsmtFinSF1'] + train_df['BsmtFinSF2']
test_df['totalsf'] = test_df['1stFlrSF'] + test_df['2ndFlrSF'] + test_df['BsmtFinSF1'] + test_df['BsmtFinSF2']

# %%
train_df['totalarea'] = train_df['GrLivArea'] + train_df['TotalBsmtSF']
test_df['totalarea'] = test_df['GrLivArea'] + test_df['TotalBsmtSF']

# %%
train_df['totalbaths'] = train_df['BsmtFullBath'] + train_df['FullBath'] + 0.5 * (train_df['BsmtHalfBath'] + train_df['HalfBath']) 
test_df['totalbaths'] = test_df['BsmtFullBath'] + test_df['FullBath'] + 0.5 * (test_df['BsmtHalfBath'] + test_df['HalfBath'])

# %%
train_df['totalporchsf'] = train_df['OpenPorchSF'] + train_df['3SsnPorch'] + train_df['EnclosedPorch'] + train_df['ScreenPorch'] + train_df['WoodDeckSF']
test_df['totalporchsf'] = test_df['OpenPorchSF'] + test_df['3SsnPorch'] + test_df['EnclosedPorch'] + test_df['ScreenPorch'] + test_df['WoodDeckSF']

# %%
train_df = train_df.drop(columns=['Id','YrSold', 'YearBuilt', 'YearRemodAdd', '1stFlrSF', '2ndFlrSF', 'BsmtFinSF1', 'BsmtFinSF2', 'GrLivArea', 'TotalBsmtSF','BsmtFullBath', 'FullBath', 'BsmtHalfBath', 'HalfBath', 'OpenPorchSF', '3SsnPorch', 'EnclosedPorch', 'ScreenPorch','WoodDeckSF'])
test_df = test_df.drop(columns=['YrSold', 'YearBuilt', 'YearRemodAdd', '1stFlrSF', '2ndFlrSF', 'BsmtFinSF1', 'BsmtFinSF2', 'GrLivArea', 'TotalBsmtSF','BsmtFullBath', 'FullBath', 'BsmtHalfBath', 'HalfBath', 'OpenPorchSF', '3SsnPorch', 'EnclosedPorch', 'ScreenPorch','WoodDeckSF'])

# %%
correlation_matrix = train_df.corr(numeric_only=True)
plt.figure(figsize=(20,12))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
# Out:
# <Axes: >

# %%
#drop GarageArea or GarageCars
# drop totalsf
# remember to give the columns with a higher correlation to saleprice a higher weight in predicting the sale price

# %%
train_df = train_df.drop(columns=['GarageArea'])
test_df = test_df.drop(columns=['GarageArea'])
train_df = train_df.drop(columns=['totalsf'])
test_df = test_df.drop(columns=['totalsf'])

# %%
sns.histplot(
    train_df,
    x=train_df['SalePrice']
)
# Out:
# <Axes: xlabel='SalePrice', ylabel='Count'>

# %%
train_df['SalePrice'] = np.log1p(train_df['SalePrice'])

# %%
sns.histplot(
    train_df,
    x=train_df['SalePrice']
)
# Out:
# <Axes: xlabel='SalePrice', ylabel='Count'>

# %%
# time to put the weighing part into play
corr = train_df.corr(numeric_only=True)

sale_corr = corr["SalePrice"].sort_values(ascending=False)

sale_corr.head(20)
# Out:
# SalePrice       1.000000
# OverallQual     0.812432
# totalarea       0.806360
# GarageCars      0.679462
# totalbaths      0.671332
# TotRmsAbvGrd    0.511744
# Fireplaces      0.470118
# MasVnrArea      0.417280
# totalporchsf    0.398192
# LotArea         0.333072
# BsmtUnfSF       0.225730
# BedroomAbvGr    0.203595
# LotFrontage     0.164588
# MoSold          0.070499
# PoolArea        0.038104
# MiscVal        -0.020825
# OverallCond    -0.053966
# MSSubClass     -0.077036
# LowQualFinSF   -0.077320
# KitchenAbvGr   -0.151972
# Name: SalePrice, dtype: float64

# %%
important = sale_corr[abs(sale_corr) > 0.2]

# %%
train_df[important.index].corr()
# Out:
#                  SalePrice  OverallQual  totalarea  GarageCars  totalbaths  \
# SalePrice         1.000000     0.812432   0.806360    0.679462    0.671332
# OverallQual       0.812432     1.000000   0.655473    0.596057    0.527346
# totalarea         0.806360     0.655473   1.000000    0.547339    0.596421
# GarageCars        0.679462     0.596057   0.547339    1.000000    0.495802
# totalbaths        0.671332     0.527346   0.596421    0.495802    1.000000
# TotRmsAbvGrd      0.511744     0.395527   0.667985    0.346344    0.447197
# Fireplaces        0.470118     0.371869   0.452525    0.279876    0.310923
# MasVnrArea        0.417280     0.390264   0.415713    0.364743    0.295388
# totalporchsf      0.398192     0.289063   0.380809    0.219829    0.306623
# LotArea           0.333072     0.116731   0.354497    0.222350    0.196587
# BsmtUnfSF         0.225730     0.313544   0.414392    0.208699   -0.106982
# BedroomAbvGr      0.203595     0.095698   0.380992    0.095636    0.232852
# houseremodelage  -0.571865    -0.548325  -0.343050   -0.421639   -0.442511
# houseage         -0.620004    -0.594688  -0.375802   -0.561817   -0.538222
#
#                  TotRmsAbvGrd  Fireplaces  MasVnrArea  totalporchsf   LotArea  \
# SalePrice            0.511744    0.470118    0.417280      0.398192  0.333072
# OverallQual          0.395527    0.371869    0.390264      0.289063  0.116731
# totalarea            0.667985    0.452525    0.415713      0.380809  0.354497
# GarageCars           0.346344    0.279876    0.364743      0.219829  0.222350
# totalbaths           0.447197    0.310923    0.295388      0.306623  0.196587
# TotRmsAbvGrd         1.000000    0.306268    0.261494      0.235449  0.276872
# Fireplaces           0.306268    1.000000    0.237877      0.270452  0.308693
# MasVnrArea           0.261494    0.237877    1.000000      0.159868  0.085653
# totalporchsf         0.235449    0.270452    0.159868      1.000000  0.234900
# LotArea              0.276872    0.308693    0.085653      0.234900  1.000000
# BsmtUnfSF            0.240115    0.050588    0.127123      0.044481  0.052214
# BedroomAbvGr         0.695938    0.102184    0.111818      0.097148  0.214634
# houseremodelage     -0.173572   -0.099186   -0.161491     -0.186280 -0.012737
# houseage            -0.107120   -0.146182   -0.304400     -0.122081 -0.032068
#
#                  BsmtUnfSF  BedroomAbvGr  houseremodelage  houseage
# SalePrice         0.225730      0.203595        -0.571865 -0.620004
# OverallQual       0.313544      0.095698        -0.548325 -0.594688
# totalarea         0.414392      0.380992        -0.343050 -0.375802
# GarageCars        0.208699      0.095636        -0.421639 -0.561817
# totalbaths       -0.106982      0.232852        -0.442511 -0.538222
# TotRmsAbvGrd      0.240115      0.695938        -0.173572 -0.107120
# Fireplaces        0.050588      0.102184        -0.099186 -0.146182
# MasVnrArea        0.127123      0.111818        -0.161491 -0.304400
# totalporchsf      0.044481      0.097148        -0.186280 -0.122081
# LotArea           0.052214      0.214634        -0.012737 -0.032068
# BsmtUnfSF         1.000000      0.159599        -0.179174 -0.167398
# BedroomAbvGr      0.159599      1.000000         0.047289  0.059170
# houseremodelage  -0.179174      0.047289         1.000000  0.605192
# houseage         -0.167398      0.059170         0.605192  1.000000

# %%
train_df.dtypes[train_df.dtypes=='object']
# Out:
# MSZoning         object
# Street           object
# LotShape         object
# LandContour      object
# Utilities        object
# LotConfig        object
# LandSlope        object
# Neighborhood     object
# Condition1       object
# Condition2       object
# BldgType         object
# HouseStyle       object
# RoofStyle        object
# RoofMatl         object
# Exterior1st      object
# Exterior2nd      object
# MasVnrType       object
# ExterQual        object
# ExterCond        object
# Foundation       object
# BsmtQual         object
# BsmtCond         object
# BsmtExposure     object
# BsmtFinType1     object
# Heating          object
# HeatingQC        object
# CentralAir       object
# Electrical       object
# KitchenQual      object
# Functional       object
# FireplaceQu      object
# GarageType       object
# GarageFinish     object
# GarageQual       object
# PavedDrive       object
# SaleType         object
# SaleCondition    object
# dtype: object

# %%
train_df.dtypes[train_df.dtypes !='object']
# Out:
# MSSubClass           int64
# LotFrontage        float64
# LotArea              int64
# OverallQual          int64
# OverallCond          int64
# MasVnrArea         float64
# BsmtUnfSF            int64
# LowQualFinSF         int64
# BedroomAbvGr         int64
# KitchenAbvGr         int64
# TotRmsAbvGrd         int64
# Fireplaces           int64
# GarageCars           int64
# PoolArea             int64
# MiscVal              int64
# MoSold               int64
# SalePrice          float64
# houseage             int64
# houseremodelage      int64
# totalarea            int64
# totalbaths         float64
# totalporchsf         int64
# dtype: object

# %%
ode_cols = ['LotShape', 'LandContour','Utilities','LandSlope',  'BsmtQual',  'BsmtFinType1',  'CentralAir',  'Functional', \
           'FireplaceQu', 'GarageFinish', 'GarageQual', 'PavedDrive', 'ExterCond', 'KitchenQual', 'BsmtExposure', 'HeatingQC','ExterQual', 'BsmtCond']

# %%
ohe_cols = ['Street', 'LotConfig','Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle', 'RoofStyle', 'Exterior1st', 'Exterior2nd', \
           'MasVnrType','Foundation',  'Electrical',  'SaleType', 'MSZoning', 'SaleCondition', 'Heating', 'GarageType', 'RoofMatl']

# %%
num_cols = train_df.select_dtypes(include=['int64', 'float64']).columns
num_cols = num_cols.drop('SalePrice')

# %%
num_pipeline = Pipeline(steps=[
    ('impute', SimpleImputer(strategy='mean')),
    ('scaler', StandardScaler())
])

# %%
ode_pipeline = Pipeline(steps=[
    ('impute', SimpleImputer(strategy='most_frequent')),
    ('ode', OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1))
])

# %%
ohe_pipeline = Pipeline(steps=[
    ('impute', SimpleImputer(strategy='most_frequent')),
    ('ohe', OneHotEncoder(handle_unknown='ignore', sparse_output=False))
])

# %%
col_trans = ColumnTransformer(transformers=[
    ('num_p', num_pipeline, num_cols),
    ('ode_p', ode_pipeline, ode_cols),
    ('ohe_p', ohe_pipeline, ohe_cols),
    ],
    remainder='passthrough', 
    n_jobs=-1)

# %%
pipeline = Pipeline(steps=[
    ('preprocessing', col_trans)
])

# %%
X = train_df.drop('SalePrice', axis=1)
y = train_df['SalePrice']

# %%
X_preprocessed = pipeline.fit_transform(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_preprocessed, y, test_size=0.2, random_state=25)

# %%
#build models

# %%
lr = LinearRegression()

# %%
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred_lr = lr.predict(X_test)

# %%
lr.score(X_test, y_test)
# Out:
# -1.1602446341317442e+19

# %%
mean_squared_error(y_test, y_pred_lr)
# Out:
# 1.6902285375074417e+18

# %%
RFR = RandomForestRegressor(random_state=13)

# %%
param_grid_RFR = {
    'max_depth': [5, 10, 15],
    'n_estimators': [100, 250, 500],
    'min_samples_split': [3, 5, 10]
}

# %%
rfr_cv = GridSearchCV(RFR, param_grid_RFR, cv=5, scoring='neg_mean_squared_error', n_jobs=-1)

# %%
rfr_cv.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(random_state=13), n_jobs=-1,
#              param_grid={'max_depth': [5, 10, 15],
#                          'min_samples_split': [3, 5, 10],
#                          'n_estimators': [100, 250, 500]},
#              scoring='neg_mean_squared_error')

# %%
np.sqrt(-1 * rfr_cv.best_score_)
# Out:
# 0.13457046703740125

# %%
rfr_cv.best_params_
# Out:
# {'max_depth': 15, 'min_samples_split': 3, 'n_estimators': 500}

# %%
XGB = XGBRegressor(random_state=13)

# %%
param_grid_XGB = {
    'learning_rate': [0.05, 0.1, 0.2],
    'n_estimators': [300],
    'max_depth': [3],
    'min_child_weight': [1,2,3],
    'gamma': [0, 0.1, 0.2],
    'subsample': [0.8, 0.9, 1.0],
    'colsample_bytree': [0.8, 0.9, 1.0],
}

# %%
xgb_cv = GridSearchCV(XGB, param_grid_XGB, cv=3, scoring='neg_mean_squared_error', n_jobs=-1)

# %%
xgb_cv.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=3,
#              estimator=XGBRegressor(base_score=None, booster=None,
#                                     callbacks=None, colsample_bylevel=None,
#                                     colsample_bynode=None,
#                                     colsample_bytree=None,
#                                     early_stopping_rounds=None,
#                                     enable_categorical=False, eval_metric=None,
#                                     feature_types=None, gamma=None, gpu_id=None,
#                                     grow_policy=None, importance_type=None,
#                                     interaction_constraints=None,
#                                     learning_rate=None, m...
#                                     min_child_weight=None, missing=nan,
#                                     monotone_constraints=None, n_estimators=100,
#                                     n_jobs=None, num_parallel_tree=None,
#                                     predictor=None, random_state=13, ...),
#              n_jobs=-1,
#              param_grid={'colsample_bytree': [0.8, 0.9, 1.0],
#                          'gamma': [0, 0.1, 0.2],
#                          'learning_rate': [0.05, 0.1, 0.2], 'max_depth': [3],
#                          'min_child_weight': [1, 2, 3], 'n_estimators': [300],
#                          'subsample': [0.8, 0.9, 1.0]},
#              scoring='neg_mean_squared_error')

# %%
np.sqrt(-1 * xgb_cv.best_score_)
# Out:
# 0.11326984065079279

# %%
ridge = Ridge()

# %%
param_grid_ridge = {
    'alpha': [0.05, 0.1, 1, 3, 5, 10],
    'solver': ['auto', 'svd', 'cholesky', 'lsqr', 'sparse_cg', 'sag']
}

# %%
ridge_cv = GridSearchCV(ridge, param_grid_ridge, cv=5, scoring='neg_mean_squared_error', n_jobs=-1)

# %%
ridge_cv.fit(X_train, y_train)
# Out:
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# GridSearchCV(cv=5, estimator=Ridge(), n_jobs=-1,
#              param_grid={'alpha': [0.05, 0.1, 1, 3, 5, 10],
#                          'solver': ['auto', 'svd', 'cholesky', 'lsqr',
#                                     'sparse_cg', 'sag']},
#              scoring='neg_mean_squared_error')

# %%
np.sqrt(-1 * ridge_cv.best_score_)
# Out:
# 0.10865820944993922

# %%
GBR = GradientBoostingRegressor()

# %%
param_grid_GBR = {
    'max_depth': [12, 15, 20],
    'n_estimators': [200, 300, 1000],
    'min_samples_leaf': [10, 25, 50],
    'learning_rate': [0.001, 0.01, 0.1],
    'max_features': [0.01, 0.1, 0.7]
}

# %%
GBR_cv = GridSearchCV(GBR, param_grid_GBR, cv=5, scoring='neg_mean_squared_error', n_jobs=-1)

# %%
GBR_cv.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=GradientBoostingRegressor(), n_jobs=-1,
#              param_grid={'learning_rate': [0.001, 0.01, 0.1],
#                          'max_depth': [12, 15, 20],
#                          'max_features': [0.01, 0.1, 0.7],
#                          'min_samples_leaf': [10, 25, 50],
#                          'n_estimators': [200, 300, 1000]},
#              scoring='neg_mean_squared_error')

# %%
np.sqrt(-1 * GBR_cv.best_score_)
# Out:
# 0.11208269689169795

# %%
lgbm_regressor = lgb.LGBMRegressor()

# %%
param_grid_lgbm = {
    'boosting_type': ['gbdt', 'dart'],
    'num_leaves': [20, 30, 40],
    'learning_rate': [0.01, 0.05, 0.1],
    'n_estimators': [100, 200, 300]
}

# %%
lgbm_cv = GridSearchCV(lgbm_regressor, param_grid_lgbm, cv=3, scoring='neg_mean_squared_error', n_jobs=-1)

# %%
lgbm_cv.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=3, estimator=LGBMRegressor(), n_jobs=-1,
#              param_grid={'boosting_type': ['gbdt', 'dart'],
#                          'learning_rate': [0.01, 0.05, 0.1],
#                          'n_estimators': [100, 200, 300],
#                          'num_leaves': [20, 30, 40]},
#              scoring='neg_mean_squared_error')

# %%
np.sqrt(-1 * lgbm_cv.best_score_)
# Out:
# 0.11840093461791805

# %%
catboost = CatBoostRegressor(loss_function='RMSE', verbose=False)

# %%
param_grid_cat ={
    'iterations': [100, 500, 1000],
    'depth': [4, 6, 8, 10],
    'learning_rate': [0.01, 0.05, 0.1, 0.5]
}

# %%
cat_cv = GridSearchCV(catboost, param_grid_cat, cv=3, scoring='neg_mean_squared_error', n_jobs=-1)

# %%
cat_cv.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=3,
#              estimator=<catboost.core.CatBoostRegressor object at 0x79ecdbb028c0>,
#              n_jobs=-1,
#              param_grid={'depth': [4, 6, 8, 10], 'iterations': [100, 500, 1000],
#                          'learning_rate': [0.01, 0.05, 0.1, 0.5]},
#              scoring='neg_mean_squared_error')

# %%
np.sqrt(-1 * cat_cv.best_score_)
# Out:
# 0.11139630221072637

# %%
vr = VotingRegressor([('gbr', GBR_cv.best_estimator_),
                      ('xgb', xgb_cv.best_estimator_),
                      ('ridge', ridge_cv.best_estimator_)],
                    weights=[2,3,1])

# %%
vr.fit(X_train, y_train)
# Out:
# VotingRegressor(estimators=[('gbr',
#                              GradientBoostingRegressor(learning_rate=0.01,
#                                                        max_depth=20,
#                                                        max_features=0.1,
#                                                        min_samples_leaf=25,
#                                                        n_estimators=1000)),
#                             ('xgb',
#                              XGBRegressor(base_score=None, booster=None,
#                                           callbacks=None,
#                                           colsample_bylevel=None,
#                                           colsample_bynode=None,
#                                           colsample_bytree=0.8,
#                                           early_stopping_rounds=None,
#                                           enable_categorical=False,
#                                           eval_metric=None, f...
#                                           interaction_constraints=None,
#                                           learning_rate=0.1, max_bin=None,
#                                           max_cat_threshold=None,
#                                           max_cat_to_onehot=None,
#                                           max_delta_step=None, max_depth=3,
#                                           max_leaves=None, min_child_weight=1,
#                                           missing=nan,
#                                           monotone_constraints=None,
#                                           n_estimators=300, n_jobs=None,
#                                           num_parallel_tree=None,
#                                           predictor=None, random_state=13, ...)),
#                             ('ridge', Ridge(alpha=10, solver='lsqr'))],
#                 weights=[2, 3, 1])

# %%
y_pred_vr = vr.predict(X_test)

# %%
mean_squared_error(y_test, y_pred_vr, squared=False)
# Out:
# 0.1186501643311326

# %%
estimators = [
    ('gbr', GBR_cv.best_estimator_),
    ('xgb', xgb_cv.best_estimator_),
    ('cat', cat_cv.best_estimator_),
    ('lgb', lgbm_cv.best_estimator_),
    ('rfr', rfr_cv.best_estimator_),
]

# %%
stackreg = StackingRegressor(
            estimators = estimators,
            final_estimator = vr
)

# %%
stackreg.fit(X_train, y_train)
# Out:
# StackingRegressor(estimators=[('gbr',
#                                GradientBoostingRegressor(learning_rate=0.01,
#                                                          max_depth=20,
#                                                          max_features=0.1,
#                                                          min_samples_leaf=25,
#                                                          n_estimators=1000)),
#                               ('xgb',
#                                XGBRegressor(base_score=None, booster=None,
#                                             callbacks=None,
#                                             colsample_bylevel=None,
#                                             colsample_bynode=None,
#                                             colsample_bytree=0.8,
#                                             early_stopping_rounds=None,
#                                             enable_categorical=False,
#                                             eval_metric=None...
#                                                                             interaction_constraints=None,
#                                                                             learning_rate=0.1,
#                                                                             max_bin=None,
#                                                                             max_cat_threshold=None,
#                                                                             max_cat_to_onehot=None,
#                                                                             max_delta_step=None,
#                                                                             max_depth=3,
#                                                                             max_leaves=None,
#                                                                             min_child_weight=1,
#                                                                             missing=nan,
#                                                                             monotone_constraints=None,
#                                                                             n_estimators=300,
#                                                                             n_jobs=None,
#                                                                             num_parallel_tree=None,
#                                                                             predictor=None,
#                                                                             random_state=13, ...)),
#                                                               ('ridge',
#                                                                Ridge(alpha=10,
#                                                                      solver='lsqr'))],
#                                                   weights=[2, 3, 1]))

# %%
y_pred_stack = stackreg.predict(X_test)

# %%
mean_squared_error(y_test, y_pred_stack, squared=False)
# Out:
# 0.12204215963757227

# %%
df_test_preprocess = pipeline.transform(test_df)

# %%
y_stacking = np.exp(stackreg.predict(df_test_preprocess))

df_y_stacking_out = test_df[['Id']]
df_y_stacking_out['SalePrice'] = y_stacking

df_y_stacking_out.to_csv('submission.csv', index=False)
# Out:
# /tmp/ipykernel_20/176896153.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_y_stacking_out['SalePrice'] = y_stacking
